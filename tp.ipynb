# %%
from PIL import Image
import matplotlib.pyplot as plt
import os
import random

img_path = os.path.join("data/images/sentinel", random.choice(os.listdir("data/images/sentinel")))
img = Image.open(img_path)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))
